# %%
import googlemaps
import pandas as pd
import time

# Replace API_KEY with your own API key obtained from the Google Cloud Console
gmaps = googlemaps.Client(key='AIzaSyDcCiwrmpFpy0MR4k9cHj63o4MY7Q3YHJQ')

# Define a list of counties in California
counties = ['Alameda', 'Alpine', 'Amador', 'Butte', 'Calaveras', 'Colusa', 'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno', 'Glenn', 'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen', 'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino', 'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange', 'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito', 'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin', 'San Luis Obispo', 'San Mateo', 'Santa Barbara', 'Santa Clara', 'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 'Solano', 'Sonoma', 'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne', 'Ventura', 'Yolo', 'Yuba']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', California', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', California', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', California', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=5000, type='restaurant')

        # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=5000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

df
# Out:
#        County                                               Name  \
# 0     Alameda             Doug Siden Visitor Center at Crab Cove
# 1     Alameda                             Pacific Pinball Museum
# 2     Alameda                            Sand Castle Picnic Area
# 3     Alameda                           Alameda Naval Air Museum
# 4     Alameda                                     Alameda Museum
# ...       ...                                                ...
# 5816     Yuba              Sutter Surgical Hospital North Valley
# 5817     Yuba                     North Valley Behavioral Health
# 5818     Yuba                  Ampla Health Yuba City Pediatrics
# 5819     Yuba  Pain Management: Sutter Medical Care Center: S...
# 5820     Yuba  Neurology: Sutter Medical Care Center (Yuba Ci...
#
#                                                 Address        Lat  \
# 0      1252 McKay Ave, Alameda, CA 94501, United States  37.768918
# 1     1510 Webster St, Alameda, CA 94501, United States  37.773798
# 2     Biking/Hiking Trail, Alameda, CA 94501, United...  37.764646
# 3     2151 Ferry Point, Alameda, CA 94501, United St...  37.781421
# 4     2324 Alameda Ave, Alameda, CA 94501, United St...  37.763542
# ...                                                 ...        ...
# 5816                    455 Plumas Boulevard, Yuba City  39.132047
# 5817                      1535 Plumas Street, Yuba City  39.153580
# 5818                       931 Market Street, Yuba City  39.144990
# 5819                    460 Plumas Boulevard, Yuba City  39.132159
# 5820            460 Plumas Boulevard Ste 203, Yuba City  39.132159
#
#              Lng        Type
# 0    -122.278299     tourist
# 1    -122.276636     tourist
# 2    -122.273355     tourist
# 3    -122.299170     tourist
# 4    -122.244161     tourist
# ...          ...         ...
# 5816 -121.613376  healthcare
# 5817 -121.617431  healthcare
# 5818 -121.613918  healthcare
# 5819 -121.614429  healthcare
# 5820 -121.614429  healthcare
#
# [5821 rows x 6 columns]

# %%
df["State"] = "California"

# %%
df.to_csv("cal_df.csv")

# %% [markdown]
# TEXAS details

# %%
# Define a list of counties in Texas
counties = ['Anderson', 'Andrews', 'Angelina', 'Aransas', 'Archer', 'Armstrong', 'Atascosa', 'Austin', 'Bailey', 'Bandera', 'Bastrop', 'Baylor', 'Bee', 'Bell', 'Bexar', 'Blanco', 'Borden', 'Bosque', 'Bowie', 'Brazoria', 'Brazos', 'Brewster', 'Briscoe', 'Brooks', 'Brown', 'Burleson', 'Burnet', 'Caldwell', 'Calhoun', 'Callahan', 'Cameron', 'Camp', 'Carson', 'Cass', 'Castro', 'Chambers', 'Cherokee', 'Childress', 'Clay', 'Cochran', 'Coke', 'Coleman', 'Collin', 'Collingsworth', 'Colorado', 'Comal', 'Comanche', 'Concho', 'Cooke', 'Coryell', 'Cottle', 'Crane', 'Crockett', 'Crosby', 'Culberson', 'Dallam', 'Dallas', 'Dawson', 'Deaf Smith', 'Delta', 'Denton', 'DeWitt', 'Dickens', 'Dimmit', 'Donley', 'Duval', 'Eastland', 'Ector', 'Edwards', 'Ellis', 'El Paso', 'Erath', 'Falls', 'Fannin', 'Fayette', 'Fisher', 'Floyd', 'Foard', 'Fort Bend', 'Franklin', 'Freestone', 'Frio', 'Gaines', 'Galveston', 'Garza', 'Gillespie', 'Glasscock', 'Goliad', 'Gonzales', 'Gray', 'Grayson', 'Gregg', 'Grimes', 'Guadalupe', 'Hale', 'Hall', 'Hamilton', 'Hansford', 'Hardeman', 'Hardin', 'Harris', 'Harrison', 'Hartley', 'Haskell', 'Hays', 'Hemphill', 'Henderson', 'Hidalgo', 'Hill', 'Hockley', 'Hood', 'Hopkins', 'Houston', 'Howard', 'Hudspeth', 'Hunt', 'Hutchinson', 'Irion', 'Jack', 'Jackson', 'Jasper', 'Jeff Davis', 'Jefferson', 'Jim Hogg', 'Jim Wells', 'Johnson', 'Jones', 'Karnes', 'Kaufman', 'Kendall', 'Kenedy', 'Kent', 'Kerr', 'Kimble', 'King', 'Kinney', 'Kleberg', 'Knox', 'Lamar', 'Lamb', 'Lampasas', 'La Salle', 'Lavaca', 'Lee', 'Leon', 'Liberty', 'Limestone', 'Lipscomb', 'Live Oak', 'Llano', 'Loving', 'Lubbock', 'Lynn', 'McCulloch', 'McLennan', 'McMullen', 'Madison', 'Marion', 'Martin', 'Mason', 'Matagorda', 'Maverick', 'Medina', 'Menard', 'Midland', 'Milam', 'Mills', 'Mitchell', 'Montague', 'Montgomery', 'Moore', 'Morris', 'Motley', 'Nacogdoches', 'Navarro', 'Newton', 'Nolan']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Texas', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Texas', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Texas', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})

        # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=5000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=5000, type='hospital')

    

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

t_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

t_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/gokulnair/Documents/GitHub/Trippi/scrapper.ipynb Cell 5 in <cell line: 8>()
#      <a href='vscode-notebook-cell:/Users/gokulnair/Documents/GitHub/Trippi/scrapper.ipynb#X44sZmlsZQ%3D%3D?line=45'>46</a> for place in places_result['results']:
#      <a href='vscode-notebook-cell:/Users/gokulnair/Documents/GitHub/Trippi/scrapper.ipynb#X44sZmlsZQ%3D%3D?line=46'>47</a>     name = place['name']
# ---> <a href='vscode-notebook-cell:/Users/gokulnair/Documents/GitHub/Trippi/scrapper.ipynb#X44sZmlsZQ%3D%3D?line=47'>48</a>     address = place['vicinity']
#      <a href='vscode-notebook-cell:/Users/gokulnair/Documents/GitHub/Trippi/scrapper.ipynb#X44sZmlsZQ%3D%3D?line=48'>49</a>     lat = place['geometry']['location']['lat']
#      <a href='vscode-notebook-cell:/Users/gokulnair/Documents/GitHub/Trippi/scrapper.ipynb#X44sZmlsZQ%3D%3D?line=49'>50</a>     lng = place['geometry']['location']['lng']
#
# KeyError: 'vicinity'

# %%
t_df["City"] = "Texas"
t_df
# Out:
#          County                                               Name  \
# 0      Anderson                Sam Houston Statue & Visitor Center
# 1      Anderson       Washington-on-the-Brazos State Historic Site
# 2      Anderson                         Lake Somerville State Park
# 3      Anderson                        Sam Houston Memorial Museum
# 4      Anderson                             Natural Bridge Caverns
# ...         ...                                                ...
# 13221     Nolan                       DaVita The Woodlands At Home
# 13222     Nolan                                           Licepros
# 13223     Nolan                           Sono Bello The Woodlands
# 13224     Nolan  Encompass Health Rehabilitation Hospital of Th...
# 13225     Nolan                   Millennium Physicians - Oncology
#
#                                                  Address        Lat  \
# 0        7600 TX-75, Huntsville, TX 77340, United States  30.661818
# 1      23400 Park Rd 12, Washington, TX 77880, United...  30.325911
# 2      14222 Park Rd 57, Somerville, TX 77879, United...  30.310915
# 3      1836 Sam Houston Ave, Huntsville, TX 77340, Un...  30.715585
# 4      26495 Natural Bridge Caverns Rd, San Antonio, ...  29.692410
# ...                                                  ...        ...
# 13221        9301 Pinecroft Drive suite #130, Shenandoah  30.174010
# 13222    27351 Blueberry Hill Drive #37, Oak Ridge North  30.164976
# 13223        1450 Lake Robbins Drive #360, The Woodlands  30.161850
# 13224                        18550 Interstate 45, Conroe  30.185840
# 13225                    18488 Interstate 45, Shenandoah  30.188352
#
#              Lng        Type   City
# 0     -95.510701     tourist  Texas
# 1     -96.155111     tourist  Texas
# 2     -96.663271     tourist  Texas
# 3     -95.551969     tourist  Texas
# 4     -98.342728     tourist  Texas
# ...          ...         ...    ...
# 13221 -95.457223  healthcare  Texas
# 13222 -95.440988  healthcare  Texas
# 13223 -95.456135  healthcare  Texas
# 13224 -95.454480  healthcare  Texas
# 13225 -95.455053  healthcare  Texas
#
# [13226 rows x 7 columns]

# %%
t_df.to_csv("texas_df.csv")

# %% [markdown]
# PENNSYLVANIA DF

# %%
# Define a list of counties in Pennsylvania
counties = ['Adams', 'Allegheny', 'Armstrong', 'Beaver', 'Bedford', 'Berks', 'Blair', 'Bradford', 'Bucks', 'Butler', 'Cambria', 'Cameron', 'Carbon', 'Centre', 'Chester', 'Clarion', 'Clearfield', 'Clinton', 'Columbia', 'Crawford', 'Cumberland', 'Dauphin', 'Delaware', 'Elk', 'Erie', 'Fayette', 'Forest', 'Franklin', 'Fulton', 'Greene', 'Huntingdon', 'Indiana', 'Jefferson', 'Juniata', 'Lackawanna', 'Lancaster', 'Lawrence', 'Lebanon', 'Lehigh', 'Luzerne', 'Lycoming', 'McKean', 'Mercer', 'Mifflin', 'Monroe', 'Montgomery', 'Montour', 'Northampton', 'Northumberland', 'Perry', 'Philadelphia', 'Pike', 'Potter', 'Schuylkill', 'Snyder', 'Somerset', 'Sullivan', 'Susquehanna', 'Tioga', 'Union', 'Venango', 'Warren', 'Washington', 'Wayne', 'Westmoreland', 'Wyoming', 'York']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Pennsylvania', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Pennsylvania', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Pennsylvania', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=5000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
        # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=5000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

p_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

p_df["City"] = "Pennsylvania"
# Out:
#      County                                               Name  \
# 0     Adams                                        Devil's Den
# 1     Adams                  Eisenhower National Historic Site
# 2     Adams  Gettysburg National Military Park Museum and V...
# 3     Adams                                  Jennie Wade House
# 4     Adams                                   Little Round Top
# ...     ...                                                ...
# 6034   York                                    Wellspan Health
# 6035   York              Apple hill blood donor center york pa
# 6036   York                   DaVita Saint Charles Way At Home
# 6037   York  York Palliative Care Specialists - Lung Sleep ...
# 6038   York                          York Towne Medical Center
#
#                                                 Address        Lat        Lng  \
# 0     Devil's Den, Sickles Ave, Gettysburg, PA 17325...  39.791420 -77.242438
# 1     243 Eisenhower Farm Rd, Gettysburg, PA 17325, ...  39.793866 -77.263270
# 2     1195 Baltimore Pike, Gettysburg, PA 17325, Uni...  39.811558 -77.225998
# 3     548 Baltimore St, Gettysburg, PA 17325, United...  39.823306 -77.230648
# 4        Sykes Ave, Gettysburg, PA 17325, United States  39.791698 -77.237021
# ...                                                 ...        ...        ...
# 6034                      2050 South Queen Street, York  39.938513 -76.695319
# 6035                                   apple hill, York  39.933674 -76.685124
# 6036                        308 Saint Charles Way, York  39.929457 -76.692327
# 6037                     2350 Freedom Way STE 202, York  39.933789 -76.680712
# 6038                             2350 Freedom Way, York  39.933800 -76.680701
#
#             Type
# 0        tourist
# 1        tourist
# 2        tourist
# 3        tourist
# 4        tourist
# ...          ...
# 6034  healthcare
# 6035  healthcare
# 6036  healthcare
# 6037  healthcare
# 6038  healthcare
#
# [6039 rows x 6 columns]

# %%
p_df.to_csv("penn_df.csv")

# %% [markdown]
# newyork

# %%
# Define a list of counties in New York
counties = ['Albany', 'Allegany', 'Bronx', 'Broome', 'Cattaraugus', 'Cayuga', 'Chautauqua', 'Chemung', 'Chenango', 'Clinton', 'Columbia', 'Cortland', 'Delaware', 'Dutchess', 'Erie', 'Essex', 'Franklin', 'Fulton', 'Genesee', 'Greene', 'Hamilton', 'Herkimer', 'Jefferson', 'Kings', 'Lewis', 'Livingston', 'Madison', 'Monroe', 'Montgomery', 'Nassau', 'New York', 'Niagara', 'Oneida', 'Onondaga', 'Ontario', 'Orange', 'Orleans', 'Oswego', 'Otsego', 'Putnam', 'Queens', 'Rensselaer', 'Richmond', 'Rockland', 'St. Lawrence', 'Saratoga', 'Schenectady', 'Schoharie', 'Schuyler', 'Seneca', 'Steuben', 'Suffolk', 'Sullivan', 'Tioga', 'Tompkins', 'Ulster', 'Warren', 'Washington', 'Wayne', 'Westchester', 'Wyoming', 'Yates']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', New York', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', New York', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', New York', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

ny_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

ny_df["City"] = "New York"

# %%
ny_df.to_csv("ny_df.csv")

# %% [markdown]
# ALASKA

# %%
# Define a list of counties in Alaska
counties = ['Aleutians East Borough', 'Aleutians West Census Area', 'Anchorage Municipality', 'Bethel Census Area', 'Bristol Bay Borough', 'Denali Borough', 'Dillingham Census Area', 'Fairbanks North Star Borough', 'Haines Borough', 'Hoonah-Angoon Census Area', 'Juneau City and Borough', 'Kenai Peninsula Borough', 'Ketchikan Gateway Borough', 'Kodiak Island Borough', 'Lake and Peninsula Borough', 'Matanuska-Susitna Borough', 'Nome Census Area', 'North Slope Borough', 'Northwest Arctic Borough', 'Petersburg Borough', 'Prince of Wales-Hyder Census Area', 'Sitka City and Borough', 'Skagway Municipality', 'Southeast Fairbanks Census Area', 'Valdez-Cordova Census Area', 'Wrangell City and Borough', 'Yakutat City and Borough', 'Yukon-Koyukuk Census Area']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Alaska', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Alaska', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Alaska', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

alaska_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

alaska_df["City"] = "Alaska"

# %%
alaska_df
# Out:
#                          County  \
# 0        Aleutians East Borough
# 1        Aleutians East Borough
# 2        Aleutians East Borough
# 3        Aleutians East Borough
# 4        Aleutians East Borough
# ...                         ...
# 1898  Yukon-Koyukuk Census Area
# 1899  Yukon-Koyukuk Census Area
# 1900  Yukon-Koyukuk Census Area
# 1901  Yukon-Koyukuk Census Area
# 1902  Yukon-Koyukuk Census Area
#
#                                                 Name  \
# 0       Aleutian World War II National Historic Area
# 1                            Museum of the Aleutians
# 2                         Kenai Fjords National Park
# 3             Glacier Bay National Park and Preserve
# 4                  Denali National Park and Preserve
# ...                                              ...
# 1898                                    LUX Infusion
# 1899  Anti-Aging Testosterone and HGH Therapy Clinic
# 1900                             PHS Region Building
# 1901                    Providence Health Park Pharm
# 1902                             Men's Health Alaska
#
#                                                 Address        Lat  \
# 0                     Unalaska, AK 99692, United States  53.915987
# 1     314 Salmon Way, Unalaska, AK 99685, United States  53.882130
# 2                                 Alaska, United States  59.848674
# 3                                 Alaska, United States  58.665807
# 4     Parks Hwy, Denali National Park and Preserve, ...  63.114800
# ...                                                 ...        ...
# 1898            510 West Tudor Road Suite #1, Anchorage  61.180071
# 1899                    3400 Latouche Street, Anchorage  61.189650
# 1900                       3760 Piper Street, Anchorage  61.185923
# 1901              3851 Piper Street Ste U230, Anchorage  61.185722
# 1902                3851 Piper Street # U431, Anchorage  61.185831
#
#              Lng        Type    City
# 0    -166.514993     tourist  Alaska
# 1    -166.548883     tourist  Alaska
# 2    -150.187880     tourist  Alaska
# 3    -136.900215     tourist  Alaska
# 4    -151.192606     tourist  Alaska
# ...          ...         ...     ...
# 1898 -149.892285  healthcare  Alaska
# 1899 -149.859424  healthcare  Alaska
# 1900 -149.826293  healthcare  Alaska
# 1901 -149.822824  healthcare  Alaska
# 1902 -149.821248  healthcare  Alaska
#
# [1903 rows x 7 columns]

# %% [markdown]
# ILLONOIS

# %%
# Define a list of counties in Illinois
counties = ['Adams', 'Alexander', 'Bond', 'Boone', 'Brown', 'Bureau', 'Calhoun', 'Carroll', 'Cass', 'Champaign', 'Christian', 'Clark', 'Clay', 'Clinton', 'Coles', 'Cook', 'Crawford', 'Cumberland', 'DeKalb', 'De Witt', 'Douglas', 'DuPage', 'Edgar', 'Edwards', 'Effingham', 'Fayette', 'Ford', 'Franklin', 'Fulton', 'Gallatin', 'Greene', 'Grundy', 'Hamilton', 'Hancock', 'Hardin', 'Henderson', 'Henry', 'Iroquois', 'Jackson', 'Jasper', 'Jefferson', 'Jersey', 'Jo Daviess', 'Johnson', 'Kane', 'Kankakee', 'Kendall', 'Knox', 'Lake', 'LaSalle', 'Lawrence', 'Lee', 'Livingston', 'Logan', 'McDonough', 'McHenry', 'McLean', 'Macon', 'Macoupin', 'Madison', 'Marion', 'Marshall', 'Mason', 'Massac', 'Menard', 'Mercer', 'Monroe', 'Montgomery', 'Morgan', 'Moultrie', 'Ogle', 'Peoria', 'Perry', 'Piatt', 'Pike', 'Pope', 'Pulaski', 'Putnam', 'Randolph', 'Richland', 'Rock Island', 'St. Clair', 'Saline', 'Sangamon', 'Schuyler', 'Scott', 'Shelby', 'Stark', 'Stephenson', 'Tazewell', 'Union', 'Vermilion', 'Wabash', 'Warren', 'Washington', 'Wayne', 'White', 'Whiteside', 'Will', 'Williamson', 'Winnebago', 'Woodford']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Illinois', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Illinois', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Illinois', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

Illinois_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

Illinois_df["City"] = "Illinois"

# %%
Illinois_df.to_csv("ill_df.csv")

# %% [markdown]
# GEORGIA

# %%
# Define a list of counties in Georgia
counties = ['Appling', 'Atkinson', 'Bacon', 'Baker', 'Baldwin', 'Banks', 'Barrow', 'Bartow', 'Ben Hill', 'Berrien', 'Bibb', 'Bleckley', 'Brantley', 'Brooks', 'Bryan', 'Bulloch', 'Burke', 'Butts', 'Calhoun', 'Camden', 'Candler', 'Carroll', 'Catoosa', 'Charlton', 'Chatham', 'Chattahoochee', 'Chattooga', 'Cherokee', 'Clarke', 'Clay', 'Clayton', 'Clinch', 'Cobb', 'Coffee', 'Colquitt', 'Columbia', 'Cook', 'Coweta', 'Crawford', 'Crisp', 'Dade', 'Dawson', 'Decatur', 'DeKalb', 'Dodge', 'Dooly', 'Dougherty', 'Douglas', 'Early', 'Echols', 'Effingham', 'Elbert', 'Emanuel', 'Evans', 'Fannin', 'Fayette', 'Floyd', 'Forsyth', 'Franklin', 'Fulton', 'Gilmer', 'Glascock', 'Glynn', 'Gordon', 'Grady', 'Greene', 'Gwinnett', 'Habersham', 'Hall', 'Hancock', 'Haralson', 'Harris', 'Hart', 'Heard', 'Henry', 'Houston', 'Irwin', 'Jackson', 'Jasper', 'Jeff Davis', 'Jefferson', 'Jenkins', 'Johnson', 'Jones', 'Lamar', 'Lanier', 'Laurens', 'Lee', 'Liberty', 'Lincoln', 'Long', 'Lowndes', 'Lumpkin', 'Macon', 'Madison', 'Marion', 'McDuffie', 'McIntosh', 'Meriwether', 'Miller', 'Mitchell', 'Monroe', 'Montgomery', 'Morgan', 'Murray', 'Muscogee', 'Newton', 'Oconee', 'Oglethorpe', 'Paulding', 'Peach', 'Pickens', 'Pierce', 'Pike', 'Polk', 'Pulaski', 'Putnam', 'Quitman', 'Rabun', 'Randolph', 'Richmond', 'Rockdale', 'Schley', 'Screven', 'Seminole', 'Spalding', 'Stephens', 'Stewart', 'Sumter', 'Talbot', 'Taliaferro', 'Tattnall', 'Taylor', 'Telfair', 'Terrell', 'Thomas', 'Tift', 'Toombs', 'Towns', 'Treutlen', 'Troup', 'Turner', 'Twiggs', 'Union', 'Upson', 'Walker', 'Walton', 'Ware', 'Warren', 'Washington', 'Wayne', 'Webster', 'Wheeler', 'White', 'Whitfield', 'Wilcox', 'Wilkes', 'Wilkinson', 'Worth']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Georgia', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Georgia', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Georgia', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

Georgia_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

Georgia_df["City"] = "Georgia"

Georgia_df.to_csv("georgia.csv")

Georgia_df
# Out:
#         County                                    Name  \
# 0      Appling                    Mistletoe State Park
# 1      Appling                           Monkey Island
# 2      Appling                           Wildwood Park
# 3      Appling                West Dam Recreation Area
# 4      Appling          The Three Monkeys Island Chain
# ...        ...                                     ...
# 14809    Worth  Greenleaf Outpatient Counseling Center
# 14810    Worth              DaVita Oak Street Dialysis
# 14811    Worth            South Georgia Medical Center
# 14812    Worth           DaVita Valdosta Home Training
# 14813    Worth      Care Medical & Chiropractic Center
#
#                                                  Address        Lat  \
# 0      3725 Mistletoe Rd, Appling, GA 30802, United S...  33.643300
# 1                       Appling, GA 30802, United States  33.687924
# 2      3780 Dogwood Ln, Appling, GA 30802, United States  33.641213
# 3           Sparrow Ln, Appling, GA 30802, United States  33.657951
# 4                       Appling, GA 30802, United States  33.684687
# ...                                                  ...        ...
# 14809                      2217 Pineview Drive, Valdosta  30.860782
# 14810             2704 North Oak Street BLDG H, Valdosta  30.866026
# 14811                 2811 North Ashley Street, Valdosta  30.868782
# 14812                401 Northside Drive ste a, Valdosta  30.870911
# 14813                    2804 North Oak Street, Valdosta  30.869895
#
#              Lng        Type     City
# 0     -82.385259     tourist  Georgia
# 1     -82.234726     tourist  Georgia
# 2     -82.286811     tourist  Georgia
# 3     -82.211670     tourist  Georgia
# 4     -82.243040     tourist  Georgia
# ...          ...         ...      ...
# 14809 -83.259445  healthcare  Georgia
# 14810 -83.293571  healthcare  Georgia
# 14811 -83.286522  healthcare  Georgia
# 14812 -83.282500  healthcare  Georgia
# 14813 -83.292556  healthcare  Georgia
#
# [14814 rows x 7 columns]

# %%
import googlemaps
import pandas as pd
import time

# Replace API_KEY with your own API key obtained from the Google Cloud Console
gmaps = googlemaps.Client(key='AIzaSyCNZPKeOxiDUXQbgW5YiRGQy2gTpOPeU-c')

# Define a list of counties in florida
counties = ['Alachua', 'Baker', 'Bay', 'Bradford', 'Brevard', 'Broward', 'Calhoun', 'Charlotte', 'Citrus', 'Clay', 'Collier', 'Columbia', 'DeSoto', 'Dixie', 'Duval', 'Escambia', 'Flagler', 'Franklin', 'Gadsden', 'Gilchrist', 'Glades', 'Gulf', 'Hamilton', 'Hardee', 'Hendry', 'Hernando', 'Highlands', 'Hillsborough', 'Holmes', 'Indian River', 'Jackson', 'Jefferson', 'Lafayette', 'Lake', 'Lee', 'Leon', 'Levy', 'Liberty', 'Madison', 'Manatee', 'Marion', 'Martin', 'Miami-Dade', 'Monroe', 'Nassau', 'Okaloosa', 'Okeechobee', 'Orange', 'Osceola', 'Palm Beach', 'Pasco', 'Pinellas', 'Polk', 'Putnam', 'St. Johns', 'St. Lucie', 'Santa Rosa', 'Sarasota', 'Seminole', 'Sumter', 'Suwannee', 'Taylor', 'Union', 'Volusia', 'Wakulla', 'Walton', 'Washington']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Florida', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', florida', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', florida', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

florida_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

florida_df["City"] = "florida"

florida_df.to_csv("florida.csv")

# %% [markdown]
# VIRGINIA

# %%
# import googlemaps
# import pandas as pd
# import time

# # Replace API_KEY with your own API key obtained from the Google Cloud Console
# gmaps = googlemaps.Client(key='AIzaSyCNZPKeOxiDUXQbgW5YiRGQy2gTpOPeU-c')

# Define a list of counties in Virginia
counties = ['Accomack', 'Albemarle', 'Alleghany', 'Amelia', 'Amherst', 'Appomattox', 'Arlington', 'Augusta', 'Bath', 'Bedford', 'Bland', 'Botetourt', 'Brunswick', 'Buchanan', 'Buckingham', 'Campbell', 'Caroline', 'Carroll', 'Charles City', 'Charlotte', 'Chesterfield', 'Clarke', 'Craig', 'Culpeper', 'Cumberland', 'Dickenson', 'Dinwiddie', 'Essex', 'Fairfax', 'Fauquier', 'Floyd', 'Fluvanna', 'Franklin', 'Frederick', 'Giles', 'Gloucester', 'Goochland', 'Grayson', 'Greene', 'Greensville', 'Halifax', 'Hanover', 'Henrico', 'Henry', 'Highland', 'Isle of Wight', 'James City', 'King and Queen', 'King George', 'King William', 'Lancaster', 'Lee', 'Loudoun', 'Louisa', 'Lunenburg', 'Madison', 'Mathews', 'Mecklenburg', 'Middlesex', 'Montgomery', 'Nelson', 'New Kent', 'Northampton', 'Northumberland', 'Nottoway', 'Orange', 'Page', 'Patrick', 'Pittsylvania', 'Powhatan', 'Prince Edward', 'Prince George', 'Prince William', 'Pulaski', 'Rappahannock', 'Richmond', 'Roanoke', 'Rockbridge', 'Rockingham', 'Russell', 'Scott', 'Shenandoah', 'Smyth', 'Southampton', 'Spotsylvania', 'Stafford', 'Surry', 'Sussex', 'Tazewell', 'Warren', 'Washington', 'Westmoreland', 'Wise', 'Wythe', 'York']

# Define an empty list to hold the results
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Virginia', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Virginia', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Virginia', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

Virginia_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

Virginia_df["City"] = "Virginia"

Virginia_df.to_csv("virginia_df.csv")

# %% [markdown]
# Missouri

# %%
counties = ['Adair', 'Andrew', 'Atchison', 'Audrain', 'Barry', 'Barton', 'Bates', 'Benton', 'Bollinger', 'Boone', 'Buchanan', 'Butler', 'Caldwell', 'Callaway', 'Camden', 'Cape Girardeau', 'Carroll', 'Carter', 'Cass', 'Cedar', 'Chariton', 'Christian', 'Clark', 'Clay', 'Clinton', 'Cole', 'Cooper', 'Crawford', 'Dade', 'Dallas', 'Daviess', 'DeKalb', 'Dent', 'Douglas', 'Dunklin', 'Franklin', 'Gasconade', 'Gentry', 'Greene', 'Grundy', 'Harrison', 'Henry', 'Hickory', 'Holt', 'Howard', 'Howell', 'Iron', 'Jackson', 'Jasper', 'Jefferson', 'Johnson', 'Knox', 'Laclede', 'Lafayette', 'Lawrence', 'Lewis', 'Lincoln', 'Linn', 'Livingston', 'Macon', 'Madison', 'Maries', 'Marion', 'McDonald', 'Mercer', 'Miller', 'Mississippi', 'Moniteau', 'Monroe', 'Montgomery', 'Morgan', 'New Madrid', 'Newton', 'Nodaway', 'Oregon', 'Osage', 'Ozark', 'Pemiscot', 'Perry', 'Pettis', 'Phelps', 'Pike', 'Platte', 'Polk', 'Pulaski', 'Putnam', 'Ralls', 'Randolph', 'Ray', 'Reynolds', 'Ripley', 'Saint Charles', 'Saint Clair', 'Saint Francois', 'Saint Louis', 'Saint Louis City', 'Ste. Genevieve', 'Saline', 'Schuyler', 'Scotland', 'Scott', 'Shannon', 'Shelby', 'Stoddard', 'Stone', 'Sullivan', 'Taney', 'Texas', 'Vernon', 'Warren', 'Washington', 'Wayne', 'Webster', 'Worth', 'Wright']

results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Missouri', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Missouri', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Missouri', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

Missouri_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

Missouri_df["City"] = "Missouri"

Missouri_df.to_csv("missouri_df.csv")

# %% [markdown]
# TRIAL

# %% [markdown]
# kentucy

# %%
counties = ['Adair', 'Allen', 'Anderson', 'Ballard', 'Barren', 'Bath', 'Bell', 'Boone', 'Bourbon', 'Boyd', 'Boyle', 'Bracken', 'Breathitt', 'Breckinridge', 'Bullitt', 'Butler', 'Caldwell', 'Calloway', 'Campbell', 'Carlisle', 'Carroll', 'Carter', 'Casey', 'Christian', 'Clark', 'Clay', 'Clinton', 'Crittenden', 'Cumberland', 'Daviess', 'Edmonson', 'Elliott', 'Estill', 'Fayette', 'Fleming', 'Floyd', 'Franklin', 'Fulton', 'Gallatin', 'Garrard', 'Grant', 'Graves', 'Grayson', 'Green', 'Greenup', 'Hancock', 'Hardin', 'Harlan', 'Harrison', 'Hart', 'Henderson', 'Henry', 'Hickman', 'Hopkins', 'Jackson', 'Jefferson', 'Jessamine', 'Johnson', 'Kenton', 'Knott', 'Knox', 'Larue', 'Laurel', 'Lawrence', 'Lee', 'Leslie', 'Letcher', 'Lewis', 'Lincoln', 'Livingston', 'Logan', 'Lyon', 'Madison', 'Magoffin', 'Marion', 'Marshall', 'Martin', 'Mason', 'McCracken', 'McCreary', 'McLean', 'Meade', 'Menifee', 'Mercer', 'Metcalfe', 'Monroe', 'Montgomery', 'Morgan', 'Muhlenberg', 'Nelson', 'Nicholas', 'Ohio', 'Oldham', 'Owen', 'Owsley', 'Pendleton', 'Perry', 'Pike', 'Powell', 'Pulaski', 'Robertson', 'Rockcastle', 'Rowan', 'Russell', 'Scott', 'Shelby', 'Simpson', 'Spencer', 'Taylor', 'Todd', 'Trigg', 'Trimble', 'Union', 'Warren', 'Washington', 'Wayne', 'Webster', 'Whitley', 'Wolfe', 'Woodford']

results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Kentucky', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Kentucky', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Kentucky', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

Kentucky_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

Kentucky_df["City"] = "Kentucky"

Kentucky_df.to_csv("kentucky_df.csv")

# %%
Kentucky_df
# Out:
#          County                                      Name  \
# 0         Adair                 Rock House Natural Bridge
# 1         Adair  Hidden River Cave & American Cave Museum
# 2         Adair         Kentucky Down Under Adventure Zoo
# 3         Adair                           Diamond Caverns
# 4         Adair                            Sid bell falls
# ...         ...                                       ...
# 11549  Woodford            Bingham Behavioral Health Care
# 11550  Woodford                           Union Athletics
# 11551  Woodford                              Knox Fitness
# 11552  Woodford                           Extreme Fitness
# 11553  Woodford                 Barbourville ARH Hospital
#
#                                                  Address        Lat  \
# 0                     Jamestown, KY 42629, United States  36.884678
# 1      119 E Main St, Horse Cave, KY 42749, United St...  37.179360
# 2      at Exit 58, 3700 L and North Turnpike Road, I-...  37.203049
# 3      1900 Mammoth Cave Pkwy, Park City, KY 42160, U...  37.116353
# 4      Lake Cumberland, Monticello, KY 42633, United ...  36.807071
# ...                                                  ...        ...
# 11549                      417 Knox Street, Barbourville  36.868587
# 11550                    Manchester Street, Barbourville  36.874657
# 11551         1313C Cumberland Gap Parkway, Barbourville  36.853962
# 11552                 3689 N, U.S. 25 East, Barbourville  36.912391
# 11553            80 Hospital Drive Suite 6, Barbourville  36.851295
#
#              Lng        Type      City
# 0     -85.235989     tourist  Kentucky
# 1     -85.905867     tourist  Kentucky
# 2     -85.932890     tourist  Kentucky
# 3     -86.061872     tourist  Kentucky
# 4     -85.026571     tourist  Kentucky
# ...          ...         ...       ...
# 11549 -83.883354         gym  Kentucky
# 11550 -83.888872         gym  Kentucky
# 11551 -83.863727         gym  Kentucky
# 11552 -83.899532         gym  Kentucky
# 11553 -83.870246  healthcare  Kentucky
#
# [11554 rows x 7 columns]

# %% [markdown]
# North Carolina

# %%
counties = ['Alamance', 'Alexander', 'Alleghany', 'Anson', 'Ashe', 'Avery', 'Beaufort', 'Bertie', 'Bladen', 'Brunswick', 'Buncombe', 'Burke', 'Cabarrus', 'Caldwell', 'Camden', 'Carteret', 'Caswell', 'Catawba', 'Chatham', 'Cherokee', 'Chowan', 'Clay', 'Cleveland', 'Columbus', 'Craven', 'Cumberland', 'Currituck', 'Dare', 'Davidson', 'Davie', 'Duplin', 'Durham', 'Edgecombe', 'Forsyth', 'Franklin', 'Gaston', 'Gates', 'Graham', 'Granville', 'Greene', 'Guilford', 'Halifax', 'Harnett', 'Haywood', 'Henderson', 'Hertford', 'Hoke', 'Hyde', 'Iredell', 'Jackson', 'Johnston', 'Jones', 'Lee', 'Lenoir', 'Lincoln', 'Macon', 'Madison', 'Martin', 'McDowell', 'Mecklenburg', 'Mitchell', 'Montgomery', 'Moore', 'Nash', 'New Hanover', 'Northampton', 'Onslow', 'Orange', 'Pamlico', 'Pasquotank', 'Pender', 'Perquimans', 'Person', 'Pitt', 'Polk', 'Randolph', 'Richmond', 'Robeson', 'Rockingham', 'Rowan', 'Rutherford', 'Sampson', 'Scotland', 'Stanly', 'Stokes', 'Surry', 'Swain', 'Transylvania', 'Tyrrell', 'Union', 'Vance', 'Wake', 'Warren', 'Washington', 'Watauga', 'Wayne', 'Wilkes', 'Wilson', 'Yadkin', 'Yancey']
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', North Carolina', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', North Carolina', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', North Carolina', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

North_Carolina_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

North_Carolina_df["City"] = "North Carolina"

North_Carolina_df.to_csv("nc_df.csv")

# %%
North_Carolina_df
# Out:
#         County                                          Name  \
# 0     Alamance     Alamance Battleground State Historic Site
# 1     Alamance          Children's Museum of Alamance County
# 2     Alamance             Alamance County Historical Museum
# 3     Alamance           Burlington City Park Amusement Area
# 4     Alamance                               Great Bend Park
# ...        ...                                           ...
# 9500    Yancey            Asheville Biologics & Orthopaedics
# 9501    Yancey                   Mountain Radiation Oncology
# 9502    Yancey  Planned Parenthood - Asheville Health Center
# 9503    Yancey    Allergy Partners of Western North Carolina
# 9504    Yancey       DaVita Biltmore Home Training (pd Only)
#
#                                                 Address        Lat        Lng  \
# 0       5803 NC-62, Burlington, NC 27215, United States  36.009738 -79.521028
# 1        217 S Main St, Graham, NC 27253, United States  36.066324 -79.401801
# 2     4777 South, NC-62, Burlington, NC 27215, Unite...  36.018973 -79.491013
# 3     1388 S Main St, Burlington, NC 27215, United S...  36.084456 -79.452344
# 4     350 Greenwood Dr, Burlington, NC 27217, United...  36.143683 -79.433236
# ...                                                 ...        ...        ...
# 9500                   172 Asheland Avenue D, Asheville  35.588285 -82.556024
# 9501                       21 Hospital Drive, Asheville  35.579222 -82.552245
# 9502                      68 McDowell Street, Asheville  35.582179 -82.553878
# 9503                      14 McDowell Street, Asheville  35.582753 -82.554001
# 9504              10 McDowell Street STE 110, Asheville  35.583216 -82.554141
#
#             Type            City
# 0        tourist  North Carolina
# 1        tourist  North Carolina
# 2        tourist  North Carolina
# 3        tourist  North Carolina
# 4        tourist  North Carolina
# ...          ...             ...
# 9500  healthcare  North Carolina
# 9501  healthcare  North Carolina
# 9502  healthcare  North Carolina
# 9503  healthcare  North Carolina
# 9504  healthcare  North Carolina
#
# [9505 rows x 7 columns]

# %% [markdown]
# KANSAS

# %%
counties = ['Allen', 'Anderson', 'Atchison', 'Barber', 'Barton', 'Bourbon', 'Brown', 'Butler', 'Chase', 'Chautauqua', 'Cherokee', 'Cheyenne', 'Clark', 'Clay', 'Cloud', 'Coffey', 'Comanche', 'Cowley', 'Crawford', 'Decatur', 'Dickinson', 'Doniphan', 'Douglas', 'Edwards', 'Elk', 'Ellis', 'Ellsworth', 'Finney', 'Ford', 'Franklin', 'Geary', 'Gove', 'Graham', 'Grant', 'Gray', 'Greeley', 'Greenwood', 'Hamilton', 'Harper', 'Harvey', 'Haskell', 'Hodgeman', 'Jackson', 'Jefferson', 'Jewell', 'Johnson', 'Kearny', 'Kingman', 'Kiowa', 'Labette', 'Lane', 'Leavenworth', 'Lincoln', 'Linn', 'Logan', 'Lyon', 'Marion', 'Marshall', 'McPherson', 'Meade', 'Miami', 'Mitchell', 'Montgomery', 'Morris', 'Morton', 'Nemaha', 'Neosho', 'Ness', 'Norton', 'Osage', 'Osborne', 'Ottawa', 'Pawnee', 'Phillips', 'Pottawatomie', 'Pratt', 'Rawlins', 'Reno', 'Republic', 'Rice', 'Riley', 'Rooks', 'Rush', 'Russell', 'Saline', 'Scott', 'Sedgwick', 'Seward', 'Shawnee', 'Sheridan', 'Sherman', 'Smith', 'Stafford', 'Stanton', 'Stevens', 'Sumner', 'Thomas', 'Trego', 'Wabaunsee', 'Wallace', 'Washington', 'Wichita', 'Wilson', 'Woodson', 'Wyandotte']
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Kansas', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Kansas', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', Kansas', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

Kansas_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

Kansas_df["City"] = "Kansas"

Kansas_df.to_csv("kansas_df.csv")

# %% [markdown]
# IOWA

# %%
counties = ['Adair', 'Adams', 'Allamakee', 'Appanoose', 'Audubon', 'Benton', 'Black Hawk', 'Boone', 'Bremer', 'Buchanan', 'Buena Vista', 'Butler', 'Calhoun', 'Carroll', 'Cass', 'Cedar', 'Cerro Gordo', 'Cherokee', 'Chickasaw', 'Clarke', 'Clay', 'Clayton', 'Clinton', 'Crawford', 'Dallas', 'Davis', 'Decatur', 'Delaware', 'Des Moines', 'Dickinson', 'Dubuque', 'Emmet', 'Fayette', 'Floyd', 'Franklin', 'Fremont', 'Greene', 'Grundy', 'Guthrie', 'Hamilton', 'Hancock', 'Hardin', 'Harrison', 'Henry', 'Howard', 'Humboldt', 'Ida', 'Iowa', 'Jackson', 'Jasper', 'Jefferson', 'Johnson', 'Jones', 'Keokuk', 'Kossuth', 'Lee', 'Linn', 'Louisa', 'Lucas', 'Lyon', 'Madison', 'Mahaska', 'Marion', 'Marshall', 'Mills', 'Mitchell', 'Monona', 'Monroe', 'Montgomery', 'Muscatine', 'Osceola']
results = []

# Loop through each county and make requests for tourist attractions, restaurants, and healthcare facilities
for county in counties:
    # Define the search parameters for the Google Places API
    places_result = gmaps.places(query='Tourist attractions in ' + county + ', Iowa', type='tourist_attraction')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'tourist'})
    
    # Define the search parameters for restaurants
    places_result = gmaps.places(query='Restaurants in ' + county + ', Iowa', type='restaurant')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})
    
    # Define the search parameters for healthcare facilities
    places_result = gmaps.places(query='Hospitals in ' + county + ', iowa', type='hospital')
    
    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['formatted_address']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']
        
        results.append({'County': county, 'Name': name,"Address":address,"Lat":lat,"Long":lng,'Type': 'heathcare'})
    
    # Search for nearby restaurants
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='restaurant')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'restaurant'})

        # Search for nearby gyms
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='gym')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'gym'})

    # Search for nearby healthcare facilities
    places_result = gmaps.places_nearby(location=(lat, lng), radius=10000, type='hospital')

    # Extract the relevant information from the API response and append it to the results list
    for place in places_result['results']:
        name = place['name']
        address = place['vicinity']
        lat = place['geometry']['location']['lat']
        lng = place['geometry']['location']['lng']

        results.append({'County': county, 'Name': name, 'Address': address, 'Lat': lat, 'Lng': lng, 'Type': 'healthcare'})

iowa_df = pd.DataFrame(results, columns=['County', 'Name', 'Address', 'Lat', 'Lng', 'Type'])

iowa_df["City"] = "Iowa"

iowa_df.to_csv("iowa_df.csv")

# %%
Kansas_df
# Out:
#          County                                               Name  \
# 0         Allen                   Pillsbury Crossing Wildlife Area
# 1         Allen                                Evel Knievel Museum
# 2         Allen                       William Allen White Historic
# 3         Allen                Tallgrass Prairie National Preserve
# 4         Allen                              Spencer Museum of Art
# ...         ...                                                ...
# 8539  Wyandotte                 MidAmerica Rehabilitation Hospital
# 8540  Wyandotte         Children's Mercy College Boulevard Clinics
# 8541  Wyandotte  Kansas Regenerative Medicine Center - Kansas City
# 8542  Wyandotte                          Stockridge Mens Medcenter
# 8543  Wyandotte                          Providence Cardiovascular
#
#                                                 Address        Lat        Lng  \
# 0     2464-2484 Pillsbury Crossing Ln, Manhattan, KS...  39.129096 -96.440017
# 1     2047 SW Topeka Blvd, Topeka, KS 66612, United ...  39.030181 -95.683573
# 2     927 Exchange St, Emporia, KS 66801, United States  38.409619 -96.175335
# 3     2480B KS-177, Strong City, KS 66869, United St...  38.442625 -96.573000
# 4     1301 Mississippi St, Lawrence, KS 66045, Unite...  38.959649 -95.244444
# ...                                                 ...        ...        ...
# 8539              5701 West 110th Street, Overland Park  38.928923 -94.651378
# 8540        5520 College Boulevard # 440, Overland Park  38.928240 -94.650087
# 8541              6650 West 110th Street, Overland Park  38.930098 -94.661944
# 8542              5401 College Boulevard # 203, Leawood  38.926905 -94.648150
# 8543                    4801 College Boulevard, Leawood  38.927079 -94.642042
#
#             Type    City
# 0        tourist  Kansas
# 1        tourist  Kansas
# 2        tourist  Kansas
# 3        tourist  Kansas
# 4        tourist  Kansas
# ...          ...     ...
# 8539  healthcare  Kansas
# 8540  healthcare  Kansas
# 8541  healthcare  Kansas
# 8542  healthcare  Kansas
# 8543  healthcare  Kansas
#
# [8544 rows x 7 columns]

# %% [markdown]
# MERGED

# %%
dff = pd.read_csv("merged.csv")

# %%
mask_lat = dff["Lat"].notna()
mask_lng = dff["Lng"].notna()
dff = dff[mask_lat & mask_lng]

# %%
dff
# Out:
#         Unnamed: 0   County  \
# 0                0  Alachua
# 1                1  Alachua
# 2                2  Alachua
# 3                3  Alachua
# 4                4  Alachua
# ...            ...      ...
# 118403       13221    Nolan
# 118404       13222    Nolan
# 118405       13223    Nolan
# 118406       13224    Nolan
# 118407       13225    Nolan
#
#                                                      Name  \
# 0                Devil's Millhopper Geological State Park
# 1                                     Mill Creek Preserve
# 2              Florida Museum of Natural History-Exhibits
# 3                 San Felasco Hammock Preserve State Park
# 4                                        Poe Springs Park
# ...                                                   ...
# 118403                       DaVita The Woodlands At Home
# 118404                                           Licepros
# 118405                           Sono Bello The Woodlands
# 118406  Encompass Health Rehabilitation Hospital of Th...
# 118407                   Millennium Physicians - Oncology
#
#                                                   Address        Lat  \
# 0       4732 Millhopper Rd, Gainesville, FL 32653, Uni...  29.704342
# 1       Parking lot off 241, NW County Road 236, and 2...  29.879777
# 2       3215 Hull Rd, Gainesville, FL 32611, United St...  29.635923
# 3       11101 Millhopper Rd, Gainesville, FL 32653, Un...  29.714285
# 4       28800 NW 182nd Ave, High Springs, FL 32643, Un...  29.823720
# ...                                                   ...        ...
# 118403        9301 Pinecroft Drive suite #130, Shenandoah  30.174010
# 118404    27351 Blueberry Hill Drive #37, Oak Ridge North  30.164976
# 118405        1450 Lake Robbins Drive #360, The Woodlands  30.161850
# 118406                        18550 Interstate 45, Conroe  30.185840
# 118407                    18488 Interstate 45, Shenandoah  30.188352
#
#               Lng        Type     City
# 0      -82.393760     tourist  florida
# 1      -82.497140     tourist  florida
# 2      -82.369855     tourist  florida
# 3      -82.460878     tourist  florida
# 4      -82.647669     tourist  florida
# ...           ...         ...      ...
# 118403 -95.457223  healthcare    Texas
# 118404 -95.440988  healthcare    Texas
# 118405 -95.456135  healthcare    Texas
# 118406 -95.454480  healthcare    Texas
# 118407 -95.455053  healthcare    Texas
#
# [100964 rows x 8 columns]

# %%
dff
# Out:
#         Unnamed: 0   County  \
# 0                0  Alachua
# 1                1  Alachua
# 2                2  Alachua
# 3                3  Alachua
# 4                4  Alachua
# ...            ...      ...
# 118403       13221    Nolan
# 118404       13222    Nolan
# 118405       13223    Nolan
# 118406       13224    Nolan
# 118407       13225    Nolan
#
#                                                      Name  \
# 0                Devil's Millhopper Geological State Park
# 1                                     Mill Creek Preserve
# 2              Florida Museum of Natural History-Exhibits
# 3                 San Felasco Hammock Preserve State Park
# 4                                        Poe Springs Park
# ...                                                   ...
# 118403                       DaVita The Woodlands At Home
# 118404                                           Licepros
# 118405                           Sono Bello The Woodlands
# 118406  Encompass Health Rehabilitation Hospital of Th...
# 118407                   Millennium Physicians - Oncology
#
#                                                   Address        Lat  \
# 0       4732 Millhopper Rd, Gainesville, FL 32653, Uni...  29.704342
# 1       Parking lot off 241, NW County Road 236, and 2...  29.879777
# 2       3215 Hull Rd, Gainesville, FL 32611, United St...  29.635923
# 3       11101 Millhopper Rd, Gainesville, FL 32653, Un...  29.714285
# 4       28800 NW 182nd Ave, High Springs, FL 32643, Un...  29.823720
# ...                                                   ...        ...
# 118403        9301 Pinecroft Drive suite #130, Shenandoah  30.174010
# 118404    27351 Blueberry Hill Drive #37, Oak Ridge North  30.164976
# 118405        1450 Lake Robbins Drive #360, The Woodlands  30.161850
# 118406                        18550 Interstate 45, Conroe  30.185840
# 118407                    18488 Interstate 45, Shenandoah  30.188352
#
#               Lng        Type     City
# 0      -82.393760     tourist  florida
# 1      -82.497140     tourist  florida
# 2      -82.369855     tourist  florida
# 3      -82.460878     tourist  florida
# 4      -82.647669     tourist  florida
# ...           ...         ...      ...
# 118403 -95.457223  healthcare    Texas
# 118404 -95.440988  healthcare    Texas
# 118405 -95.456135  healthcare    Texas
# 118406 -95.454480  healthcare    Texas
# 118407 -95.455053  healthcare    Texas
#
# [100964 rows x 8 columns]

# %%
dff = dff.iloc[:,1:]

# %%
dff = dff.reset_index(drop=True)

# %%
dff = dff.rename(columns={"City":"State"})

# %%
dff.to_csv("attractions_df.csv")
