# %%
import pandas as pd
from google.colab import files

# %%
la_reviews_df  = pd.read_csv("/content/la_reviews.csv")
nyc_reviews_df  = pd.read_csv("/content/nyc_reviews.csv")
austin_reviews_df  = pd.read_csv("/content/austin_reviews.csv")
chicago_reviews_df  = pd.read_csv("/content/chicago_reviews.csv")

# %%
concatenated_df = pd.concat([la_reviews_df, nyc_reviews_df, austin_reviews_df, chicago_reviews_df], axis=0)

# %%
concatenated_df
# Out:
#                 listing_id                  id        date  reviewer_id  \
# 0                      109              449036  2011-08-15       927861
# 1                    45392              270172  2011-05-18        92047
# 2                    45392              377312  2011-07-16       323103
# 3                      109            74506539  2016-05-15     22509885
# 4                     2708            13994902  2014-06-09     10905424
# ...                    ...                 ...         ...          ...
# 316773  638566428861724511  640567800673543417  2022-06-02    461847266
# 316774  638566428861724511  642783790945054382  2022-06-05    439783703
# 316775  638566428861724511  644145189443851645  2022-06-07    436467589
# 316776  639686013457311636  644179470202282321  2022-06-07      1729799
# 316777  640034142960477648  643504953813785838  2022-06-06    236876009
#
#        reviewer_name                                           comments
# ...

# %%
concatenated_df.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
print(concatenated_df.isnull().sum())
# Out:
# listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      5
# comments         425
# dtype: int64

# %%
concatenated_df.drop(concatenated_df[concatenated_df['comments'].isnull()].index, inplace=True)

# %%
concatenated_df.drop(concatenated_df[concatenated_df['reviewer_name'].isnull()].index, inplace=True)

# %%
print(concatenated_df.isnull().sum())
# Out:
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# comments         0
# dtype: int64

# %%
print(concatenated_df.dtypes)
# Out:
# listing_id        int64
# id                int64
# date             object
# reviewer_id       int64
# reviewer_name    object
# comments         object
# dtype: object

# %%
concatenated_df

# %%
concatenated_df['date'] = pd.to_datetime(concatenated_df['date'])

# %%
print(concatenated_df.dtypes)
# Out:
# listing_id                int64
# id                        int64
# date             datetime64[ns]
# reviewer_id               int64
# reviewer_name            object
# comments                 object
# dtype: object

# %%
concatenated_df.rename(columns={'id': 'rev_id'}, inplace=True)

# %%
concatenated_df['rev_id'].nunique()
# Out:
# 1978734

# %%
concatenated_df
# Out:
#                 listing_id              rev_id       date  reviewer_id  \
# 0                      109              449036 2011-08-15       927861
# 1                    45392              270172 2011-05-18        92047
# 2                    45392              377312 2011-07-16       323103
# 3                      109            74506539 2016-05-15     22509885
# 4                     2708            13994902 2014-06-09     10905424
# ...                    ...                 ...        ...          ...
# 316773  638566428861724511  640567800673543417 2022-06-02    461847266
# 316774  638566428861724511  642783790945054382 2022-06-05    439783703
# 316775  638566428861724511  644145189443851645 2022-06-07    436467589
# 316776  639686013457311636  644179470202282321 2022-06-07      1729799
# 316777  640034142960477648  643504953813785838 2022-06-06    236876009
#
#        reviewer_name                                           comments
# ...

# %%
duplicates = concatenated_df[concatenated_df.duplicated(['rev_id'], keep=False)]
duplicates
# Out:
#         listing_id              rev_id       date  reviewer_id reviewer_name  \
# 776326    40756238           712254862 2020-11-29    341016183       Jocelyn
# 776327    40756238           743200894 2021-03-28    354884210        Ronald
# 776328    40756238           764342674 2021-05-30     47635763         Carol
# 776329    40756238  409324747356711935 2021-07-18    176225459         Marco
# 776330    40756238  442008270927132507 2021-09-01    419634104         James
# ...            ...                 ...        ...          ...           ...
# 790600    42065564  576835805306503978 2022-03-06    110634182         Frank
# 790601    42065564  617322949531833163 2022-05-01    156249952         James
# 790602    42065564  628270687125026132 2022-05-16     18589447          Jane
# 790603    42065564  633303652636274745 2022-05-23    197171888       Ricardo
# 790604    42065564  637650534668817116 2022-05-29     15709246         Bobby
#
# ...

# %%
concatenated_df = concatenated_df.drop_duplicates(subset=['rev_id'])
reviews_df  = concatenated_df
reviews_df
# Out:
#                 listing_id              rev_id       date  reviewer_id  \
# 0                      109              449036 2011-08-15       927861
# 1                    45392              270172 2011-05-18        92047
# 2                    45392              377312 2011-07-16       323103
# 3                      109            74506539 2016-05-15     22509885
# 4                     2708            13994902 2014-06-09     10905424
# ...                    ...                 ...        ...          ...
# 316773  638566428861724511  640567800673543417 2022-06-02    461847266
# 316774  638566428861724511  642783790945054382 2022-06-05    439783703
# 316775  638566428861724511  644145189443851645 2022-06-07    436467589
# 316776  639686013457311636  644179470202282321 2022-06-07      1729799
# 316777  640034142960477648  643504953813785838 2022-06-06    236876009
#
#        reviewer_name                                           comments
# ...

# %%
concatenated_df.to_csv('reviews_cleaned.csv', index=False)
files.download('reviews_cleaned.csv')
